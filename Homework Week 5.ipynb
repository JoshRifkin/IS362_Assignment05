# %% [markdown]
# <h1>Homework Week 5</h1>
# <p>Your task in this week’s assignment is to answer three questions:<br>
# 1. What is the northernmost airport in the United States?<br>
# 2. What is the easternmost airport in the United States?<br>
# 3. On February 12th, 2013, which New York area airport had the windiest weather?</p>

# %%
import pandas as pd

# %%
airports = "airports.csv"
weather = "weather.csv"
ap_data = pd.read_csv(airports)
wthr_data = pd.read_csv(weather)

# %% [markdown]
# <h3>Finding the Northernmost airport in the United States</h3>
# <p> Finding the northernmost airport is not a terribly difficult task. It can be completed simply by sorting the airports in our dataframe by the latitudinal coordinates of each airport. Latitude is the measurment for angular distance to the north and south of the equator. The equator is located at 0 Degrees, the north pole at 90 degrees north, and the south pole at 90 degrees south.</p>

# %%
# Sort the values by the highest latitude, then print only the top 5 slots.
ap_data.sort_values(by=['lat'], ascending = False).head()
# Out:
#      faa                                        name        lat         lon  \
# 417  EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230  BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110  AIN                          Wainwright Airport  70.638056 -159.994722
# 708  K03                               Wainwright As  70.613378 -159.860350
# 152  ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
#
#      alt  tz dst              tzone
# 417  149  -5   A                NaN
# 230   44  -9   A  America/Anchorage
# 110   41  -9   A  America/Anchorage
# 708   35  -9   A  America/Anchorage
# 152   96  -9   A  America/Anchorage

# %% [markdown]
# <p>As you can see above, we printed a list of the five northernmost airports. Doing some research shows the the number one entry above seems to be a mistake. The latitude and longitude are switched.</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Finding the Easternmost airport in the United States</h3>
# <p> This can be done in much the same way as the previous problem but instead of sorting by the latitude, we will sort by longitude. Longitude is the measurment for angular distance to the east and west of the meridian in Greenwich, England.</p>

# %%
# Sort the values by the highest longitude, then print only the top 5 slots.
ap_data.sort_values(by=['lon'], ascending = True).head()
# Out:
#       faa              name        lat         lon  alt  tz dst  \
# 95    ADK      Adak Airport  51.878000 -176.646000   18  -9   A
# 112   AKB      Atka Airport  52.220278 -174.206389   56  -9   A
# 522   GAM   Gambell Airport  63.766800 -171.733000   27  -9   A
# 1281  SVA  Savoonga Airport  63.686400 -170.493000   53  -9   A
# 1251  SNP    St Paul Island  57.167333 -170.220444   63  -9   A
#
#                   tzone
# 95    America/Anchorage
# 112   America/Anchorage
# 522   America/Anchorage
# 1281  America/Anchorage
# 1251  America/Anchorage

# %% [markdown]
# <p>In the table above, we see that ADK is labeled as the easternmost airport in the United States, however, if you look at a map, you can clearly see that this airport is very far west of the United States. The reason for this is that the airport in fact crosses over the meridian line, crossing from being technically to the "west" to being the most "east".<p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p>To find the most eastern airport as we would otherwise imagine it, we will limit our table to the "New York" timezone which includes the entire eastern seaboard of the United states.</p>

# %%
ap_data[ap_data['tzone'] == 'America/New_York'].sort_values(by=['lon'], ascending = False).head()
# Out:
#       faa                                 name        lat        lon  alt  tz  \
# 444   EPM           Eastport Municipal Airport  44.910111 -67.012694   45  -5
# 624   HUL                         Houlton Intl  46.123083 -67.792056  489  -5
# 259   CAR                         Caribou Muni  46.871500 -68.017917  626  -5
# 1101  PQI  Northern Maine Rgnl At Presque Isle  46.688958 -68.044797  534  -5
# 1398  WFK  Northern Aroostook Regional Airport  47.285556 -68.312778  988  -5
#
#      dst             tzone
# 444    A  America/New_York
# 624    A  America/New_York
# 259    A  America/New_York
# 1101   A  America/New_York
# 1398   A  America/New_York

# %% [markdown]
# <p>Now, as you can see above, we've determined that the "easternmost" airport is EPM - Eastport Municipal Airport located in Maine.</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>Finding the Windiest airport in the United States on February 12, 2013</h3>

# %%
wthr_data = wthr_data[(wthr_data['month'] == 2) & (wthr_data['day'] == 12) & (wthr_data['year'] == 2013)]

# %%
wthr_data.sort_values(by=['wind_speed'], ascending=False).head()
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1009     EWR  2013      2   12     3  39.02  26.96  61.63     260.0
# 18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 18428    LGA  2013      2   12    13  44.06  23.00  43.02     300.0
# 18429    LGA  2013      2   12    14  44.06  23.00  43.02     300.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 1009   1048.36058        NaN     0.0    1008.3   10.0  2013-02-12T08:00:00Z
# 18417    23.01560   31.07106     0.0    1007.1   10.0  2013-02-12T07:00:00Z
# 1018     21.86482   31.07106     0.0    1012.5   10.0  2013-02-12T17:00:00Z
# 18428    21.86482   25.31716     0.0    1011.7   10.0  2013-02-12T18:00:00Z
# 18429    20.71404   25.31716     0.0    1011.5   10.0  2013-02-12T19:00:00Z

# %% [markdown]
# <p>As we can see in the chart above, the - seemingly - windiest airport on February 12, 2013 was EWR with wind speeds of 1048 MPH. That seemed rather high so I performed a quick google search for the windiest day in the United States. As we can see from the screenshot below. The fastest wind speeds on record took place on April 12, 1934 in Mount Washington, NH with a max wind speed of 231 MPH. As such we can determine that the first line is an error. Therefore the second entry is the correct answer. As such LGA was the windiest airport on February 12, 2013 with windspeeds of up to approximately 23 MPH.</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p>We might also consider the fact that perhaps we can measure the windiest airport based on average windspeed. However, the mistaken entry seen above will greatly swing the average. As such, we must remove that entry prior to taking the average.</p>

# %%
wthr_data.drop([1009], inplace = True)
wthr_data.reset_index(inplace = True)

# %%
wthr_data.sort_values(by=['wind_speed'], ascending=False).head()
# Out:
#     index origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 49  18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 11   1018    EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 60  18428    LGA  2013      2   12    13  44.06  23.00  43.02     300.0
# 2    1008    EWR  2013      2   12     2  39.92  28.04  62.21     270.0
# 61  18429    LGA  2013      2   12    14  44.06  23.00  43.02     300.0
#
#     wind_speed  wind_gust  precip  pressure  visib             time_hour
# 49    23.01560   31.07106     0.0    1007.1   10.0  2013-02-12T07:00:00Z
# 11    21.86482   31.07106     0.0    1012.5   10.0  2013-02-12T17:00:00Z
# 60    21.86482   25.31716     0.0    1011.7   10.0  2013-02-12T18:00:00Z
# 2     20.71404   25.31716     0.0    1007.8   10.0  2013-02-12T07:00:00Z
# 61    20.71404   25.31716     0.0    1011.5   10.0  2013-02-12T19:00:00Z

# %%
wthr_data.groupby('origin').mean().sort_values(by=['wind_speed'], ascending=False).head()
# Out:
#                index    year  month   day       hour       temp       dewp  \
# origin
# LGA     18426.500000  2013.0    2.0  12.0  11.500000  41.937500  24.305000
# JFK      9720.500000  2013.0    2.0  12.0  11.500000  41.247500  25.295000
# EWR      1017.869565  2013.0    2.0  12.0  11.869565  40.624348  26.396522
#
#             humid    wind_dir  wind_speed  wind_gust  precip     pressure  \
# origin
# LGA     49.937917  279.130435   14.960140  24.885618     0.0  1011.113043
# JFK     53.634583  279.166667   14.384750  24.584845     0.0  1011.479167
# EWR     58.029130  269.130435   13.258987  25.173313     0.0  1011.628571
#
#          visib
# origin
# LGA     10.000
# JFK      9.875
# EWR     10.000

# %% [markdown]
# <p>As you can see, the windiest airport still remains LGA with an average windspeed of 14.96 MPH on February 12, 2013.</p>

# %% [markdown]
# <h2>Final Answers</h2>
# <p><b>1. What is the northernmost airport in the United States?</b><br>
# <i>Wiley Post Will Rogers Memorial Airport located in Barrow, Alaska</i><br>
# <b>2. What is the easternmost airport in the United States?</b><br>
# <i>Eastport Municipal Airport located in Eastport, Maine</i><br>
# <b>3. On February 12th, 2013, which New York area airport had the windiest weather?</b><br>
# <i>The windiest airport in the NY Area is LGA with average wind speeds of 14.96 MPH.</i></p>
